# %% [markdown]
# <a href="https://colab.research.google.com/github/abubakarkhanlakhwera/Deepl-Learing/blob/main/MLP-Notation/MLP_Notation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MLP-Notation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-12-20 at 19.55.22_e84a23a9.jpg](data:image/jpeg;base64,...)
